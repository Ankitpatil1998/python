# %%
#text file , Excel files, XML files,json files

# %% [markdown]
# # to read text files

# %%
#syntax
#variable_to_store_file=open(r"path","module")

# %% [markdown]
# # "r":read mode()

# %%
file=open(r"C:\Users\admin\Desktop\file_operations.txt,"r")
file.read()
file.close()

# %% [markdown]
# # "w":write mode()

# %%
file=open(r"C:\Users\admin\Desktop\file_operations.txt,"w")
file.write("hello")
file.close()

# %%
file=open(r"C:\Users\admin\Desktop\file_operations.txt","w")
file.write("my name is  ankit patil")
file.close()

# %%
file=open(r"C:\Users\admin\Desktop\file_operations.txt","w")
file.write("i am from mp")
file.close()

# %%
file=open(r"C:\Users\admin\Desktop\file_operations.txt","w")
file.write("i am a python developer")
file.close()

# %%
New=open(r"C:\Users\admin\Desktop\Ankit.txt","w")
New.write("\I am python developer")
New.close()

# %% [markdown]
# # "a":append()

# %%
New=open(r"C:\Users\admin\Desktop\Ankit.txt","a")
New.write("I am  learning File operations")

New.close()

# %% [markdown]
# # "r+":read and write mode()

# %%
New=open(r"C:\Users\admin\Desktop\Ankit.txt","r+")
New.write("i am from MP")

New.close()

# %%
with open(r"C:\Users\admin\Desktop\Ankit.txt","r+") as a:
    a.write("hii")

# %%
l=["This is Pune\n","This is nagpur\n","This is Mumbai\n"]

# %%
with open(r"C:\Users\admin\Desktop\file_operations.txt","w") as a:
    a.writelines(l)

# %% [markdown]
# # TOP READ EXCEL FILES IN PYTHON

# %% [markdown]
# # pandas module()

# %%
import pandas as pd
data=pd.read_excel(r"C:\Users\admin\Desktop\New folder\Excel Sample Data.xlsx")
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data=pd.read_csv(r"‪C:\Users\admin\Desktop\sarthak floder\pyana file\FitBit data.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data=pd.read_csv(r"‪C:\Users\admin\Desktop\sarthak floder\pyana file\FitBit data.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data=pd.read_csv(r"C:\Users\admin\Desktop\sarthak floder\pyana file\Placement.csv")

data
# Out:
#          name of company                                  college name  \
# 0                XORIANT               XAVIER INSTITUTE OF ENGINEERING
# 1                XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT
# 2                XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY
# 3                QUINNOX                 PILLAI COLLEGE OF ENGINEERING
# 4                QUINNOX  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# ..                   ...                                           ...
# 457  ARK TECHNOSOLUTIONS  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY
# 458             ACCOLITE          K. J. SOMAIYA COLLEGE OF ENGINEERING
# 459             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 460             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
# 461             ACCOLITE         PUNE INSTITUTE OF COMPUTER TECHNOLOGY
#
#           region  year   Salary
# 0         MUMBAI  2018   657673
# 1           PUNE  2018   657673
# ...
